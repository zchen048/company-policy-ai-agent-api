# %%
from langchain_core.messages import BaseMessage, ToolMessage, HumanMessage, AIMessage
from IPython.display import Image, display
from agents.graphs.details_subgraph import details_graph
from agents.graphs.gen_subgraph import gen_graph

# %%
# to visualise the graph
display(Image(details_graph.get_graph().draw_mermaid_png()))

# %%
# to visualise the graph
display(Image(gen_graph.get_graph().draw_mermaid_png()))
